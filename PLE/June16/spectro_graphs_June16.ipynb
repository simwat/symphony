# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

FileNames = [0]*38
for i in range(len(FileNames)):
    string = 'Calibration (%.0f)' %(i+1)
    FileNames[i] = [string]
    print(FileNames[i])

fig = go.Figure()

for j in range(len(FileNames)):

    df = pd.read_csv(FileNames[j][0])
    dataWheader = np.array(df)

    data = dataWheader[2::]
    Wavelength = [0]*len(data) 
    Count = [0]*len(data)
    MaxLoc = [0]*len(data)
    for i in range(len(data)):
        step_0 = str(data[i]).split('\\t')
        Wavelength[i] = float(step_0[0][2::])
        Count[i] = float(step_0[1][0:-2])
    
     # Add traces
    fig.add_trace(go.Scatter(x=Wavelength, y=Count,
                    mode='lines',
                    name='%.0f' %j))

#plt.legend()
#plt.xlim(364.85, 365.025)
#lgd = ax.legend(bbox_to_anchor=(1.1, 0.1))
#text = ax.text(-0.2,1.05, "Default25to35", transform=ax.transAxes) # CHANGE K_RANGE
#go.savefig('June18_recalibration2_cursor.png', bbox_extra_artists=(lgd, text), bbox_inches='tight')

fig['layout']['xaxis'].update(title='Wavelength (nm)', range=[364.4, 365.8], dtick=0.05, autorange=False)
fig['layout']['yaxis'].update(title='Counts/sec', autorange=True)
fig.show()
# Out:
# ['Calibration (1)']
# ['Calibration (2)']
# ['Calibration (3)']
# ['Calibration (4)']
# ['Calibration (5)']
# ['Calibration (6)']
# ['Calibration (7)']
# ['Calibration (8)']
# ['Calibration (9)']
# ['Calibration (10)']
# ['Calibration (11)']
# ['Calibration (12)']
# ['Calibration (13)']
# ['Calibration (14)']
# ['Calibration (15)']
# ['Calibration (16)']
# ['Calibration (17)']
# ['Calibration (18)']
# ['Calibration (19)']
# ['Calibration (20)']
# ['Calibration (21)']
# ['Calibration (22)']
# ['Calibration (23)']
# ['Calibration (24)']
# ['Calibration (25)']
# ['Calibration (26)']
# ['Calibration (27)']
# ['Calibration (28)']
# ['Calibration (29)']
# ['Calibration (30)']
# ['Calibration (31)']
# ['Calibration (32)']
# ['Calibration (33)']
# ['Calibration (34)']
# ['Calibration (35)']
# ['Calibration (36)']
# ['Calibration (37)']
# ['Calibration (38)']
# <div>
#
#
#             <div id="cf2690f1-cb9a-43d5-a154-d539a5d7089a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf2690f1-cb9a-43d5-a154-d539a5d7089a")) {
#                     Plotly.newPlot(
#                         'cf2690f1-cb9a-43d5-a154-d539a5d7089a',
#                         [{"mode": "lines", "name": "0", "type": "scatter", "x": [364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364.965, 364.97, 364.975, 364.98, 364.985, 364.99, 364.995, 365.0, 365.005, 365.01, 365.015, 365.02, 365.025, 365.03, 365.035, 365.04, 365.045, 365.05, 365.055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 365.16, 365.165, 365.17, 365.175, 365.18, 365.185, 365.19, 365.195, 365.2, 365.205, 365.21, 365.215, 365.22, 365.225, 365.23, 365.235, 365.24, 365.245, 365.25, 365.255, 365.26, 365.265, 365.27, 365.275, 365.28, 365.285, 365.29, 365.295, 365.3, 365.305, 365.31, 365.315, 365.32, 365.325, 365.33, 365.335, 365.34, 365.345, 365.35, 365.355, 365.36, 365.365, 365.37, 365.375, 365.38, 365.385, 365.39, 365.395, 365.4, 365.405, 365.41, 365.415, 365.42, 365.425, 365.43, 365.435, 365.44, 365.445, 365.45, 365.455, 365.46, 365.465, 365.47, 365.475, 365.48, 365.485, 365.49, 365.495, 365.5, 365.505, 365.51, 365.515, 365.52, 365.525, 365.53, 365.535, 365.54, 365.545, 365.55, 365.555, 365.56, 365.565, 365.57, 365.575, 365.58, 365.585, 365.59, 365.595, 365.6, 365.605, 365.61, 365.615, 365.62, 365.625, 365.63, 365.635, 365.64, 365.645, 365.65, 365.655, 365.66, 365.665, 365.67, 365.675, 365.68, 365.685, 365.69, 365.695, 365.7, 365.705, 365.71, 365.715, 365.72, 365.725, 365.73, 365.735, 365.74, 365.745, 365.75, 365.755, 365.76, 365.765, 365.77, 365.775, 365.78, 365.785, 365.79, 365.795, 365.8], "y": [1142.0, 1070.0, 1093.0, 1199.0, 1377.0, 1486.0, 2053.0, 2521.0, 2927.0, 4667.0, 7584.0, 11309.0, 17455.0, 29470.0, 47554.0, 50865.0, 63708.0, 74736.0, 89528.0, 118317.0, 195795.0, 577276.0, 659799.0, 229857.0, 141455.0, 89023.0, 33286.0, 27897.0, 19567.0, 13044.0, 8817.0, 7737.0, 7002.0, 5404.0, 4889.0, 4822.0, 3999.0, 3567.0, 3658.0, 3208.0, 3470.0, 2619.0, 2576.0, 2169.0, 2457.0, 2558.0, 1919.0, 1968.0, 1774.0, 1544.0, 1641.0, 1432.0, 1497.0, 1247.0, 1286.0, 1301.0, 1456.0, 951.0, 1227.0, 1101.0, 665.0, 952.0, 981.0, 843.0, 1008.0, 934.0, 843.0, 1101.0, 1142.0, 899.0, 1047.0, 963.0, 884.0, 935.0, 895.0, 869.0, 779.0, 857.0, 755.0, 761.0, 790.0, 897.0, 908.0, 845.0, 835.0, 936.0, 869.0, 683.0, 1033.0, 806.0, 859.0, 935.0, 844.0, 837.0, 794.0, 986.0, 800.0, 1019.0, 1015.0, 948.0, 1264.0, 1510.0, 2226.0, 3061.0, 3906.0, 6779.0, 8311.0, 11347.0, 12358.0, 16433.0, 18785.0, 24231.0, 38463.0, 92562.0, 142686.0, 124865.0, 57545.0, 29455.0, 14531.0, 9195.0, 5063.0, 2967.0, 2127.0, 2134.0, 1644.0, 1459.0, 1310.0, 1144.0, 1239.0, 1007.0, 1022.0, 1156.0, 1040.0, 1064.0, 1233.0, 969.0, 894.0, 1153.0, 835.0, 964.0, 903.0, 855.0, 837.0, 744.0, 955.0, 613.0, 850.0, 677.0, 908.0, 671.0, 658.0, 762.0, 821.0, 842.0, 725.0, 740.0, 832.0, 752.0, 802.0, 817.0, 732.0, 743.0, 787.0, 749.0, 670.0, 693.0, 615.0, 501.0, 422.0, 343.0, 296.0, 261.0, 395.0, 347.0, 334.0, 398.0, 355.0, 355.0, 406.0, 246.0, 228.0, 329.0, 362.0, 257.0, 310.0, 234.0, 321.0, 269.0, 327.0, 396.0, 252.0, 274.0, 316.0, 155.0, 253.0, 177.0, 215.0, 254.0, 202.0, 405.0, 340.0]}, {"mode": "lines", "name": "1", "type": "scatter", "x": [364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364.965, 364.97, 364.975, 364.98, 364.985, 364.99, 364.995, 365.0, 365.005, 365.01, 365.015, 365.02, 365.025, 365.03, 365.035, 365.04, 365.045, 365.05, 365.055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 3 ...
