# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

FileNames = [0]*20
for i in range(len(FileNames)):
    string = 'Default (%.0f)' %(i+1)
    FileNames[i] = [string]
    print(FileNames[i])

fig = go.Figure()

for j in range(len(FileNames)):

    df = pd.read_csv(FileNames[j][0])
    dataWheader = np.array(df)

    data = dataWheader[2::]
    Wavelength = [0]*len(data) 
    Count = [0]*len(data)
    MaxLoc = [0]*len(data)
    for i in range(len(data)):
        step_0 = str(data[i]).split('\\t')
        Wavelength[i] = float(step_0[0][2::])
        Count[i] = float(step_0[1][0:-2])
    
     # Add traces
    fig.add_trace(go.Scatter(x=Wavelength, y=Count,
                    mode='lines',
                    name='%.0f' %j))

#plt.legend()
#plt.xlim(364.85, 365.025)
#lgd = ax.legend(bbox_to_anchor=(1.1, 0.1))
#text = ax.text(-0.2,1.05, "Default25to35", transform=ax.transAxes) # CHANGE K_RANGE
#go.savefig('June18_recalibration2_cursor.png', bbox_extra_artists=(lgd, text), bbox_inches='tight')

fig['layout']['xaxis'].update(title='Wavelength (nm)', range=[364.8, 365.05], dtick=0.01, autorange=False)
fig['layout']['yaxis'].update(title='Counts/sec', autorange=True)
fig.show()
# Out:
# ['Default (1)']
# ['Default (2)']
# ['Default (3)']
# ['Default (4)']
# ['Default (5)']
# ['Default (6)']
# ['Default (7)']
# ['Default (8)']
# ['Default (9)']
# ['Default (10)']
# ['Default (11)']
# ['Default (12)']
# ['Default (13)']
# ['Default (14)']
# ['Default (15)']
# ['Default (16)']
# ['Default (17)']
# ['Default (18)']
# ['Default (19)']
# ['Default (20)']
# <div>
#
#
#             <div id="93d5f5a3-7283-4c51-9fd1-85402e129276" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93d5f5a3-7283-4c51-9fd1-85402e129276")) {
#                     Plotly.newPlot(
#                         '93d5f5a3-7283-4c51-9fd1-85402e129276',
#                         [{"mode": "lines", "name": "0", "type": "scatter", "x": [364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364.965, 364.97, 364.975, 364.98, 364.985, 364.99, 364.995, 365.0, 365.005, 365.01, 365.015, 365.02, 365.025, 365.03, 365.035, 365.04, 365.045, 365.05, 365.055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 365.16, 365.165, 365.17, 365.175, 365.18, 365.185, 365.19, 365.195, 365.2], "y": [290.0, 177.0, 266.0, 198.0, 200.0, 257.0, 359.0, 377.0, 317.0, 306.0, 245.0, 339.0, 295.0, 334.0, 403.0, 362.0, 396.0, 259.0, 512.0, 349.0, 422.0, 550.0, 582.0, 607.0, 540.0, 554.0, 670
055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 365.16, 365.165, 365.17, 365.175, 365.18, 365.185, 365.19, 365.195, 365.2], "y": [158.0, 240.0, 292.0, 301.0, 332.0, 326.0, 275.0, 237.0, 344.0, 321.0, 376.0, 353.0, 374.0, 354.0, 360.0, 366.0, 414.0, 436.0, 603.0, 502.0, 545.0, 569.0, 628.0, 701.0, 1039.0, 1138.0, 1604.0, 2526.0, 4019.0, 7198.0, 10588.0, 14737.0, 18866.0, 24716.0, 28770.0, 31984.0, 48726.0, 68334.0, 122500.0, 228107.0, 140150.0, 59959.0, 35231.0, 21577.0, 12915.0, 7471.0, 5378.0, 3805.0, 3083.0, 2547.0, 2072.0, 1831.0, 1557.0, 1523.0, 1341.0, 1411.0, 1101.0, 1027.0, 1136.0, 982.0, 783.0, 885.0, 770.0,  ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

FileNames = [0]*24
for i in range(len(FileNames)):
    string = 'Default (%.0f)' %(i+21)
    FileNames[i] = [string]
    print(FileNames[i])

fig = go.Figure()

for j in range(len(FileNames)):

    df = pd.read_csv(FileNames[j][0])
    dataWheader = np.array(df)

    data = dataWheader[2::]
    Wavelength = [0]*len(data) 
    Count = [0]*len(data)
    MaxLoc = [0]*len(data)
    for i in range(len(data)):
        step_0 = str(data[i]).split('\\t')
        Wavelength[i] = float(step_0[0][2::])
        Count[i] = float(step_0[1][0:-2])
    
     # Add traces
    fig.add_trace(go.Scatter(x=Wavelength, y=Count,
                    mode='lines',
                    name='%.0f' %j))

#plt.legend()
#plt.xlim(364.85, 365.025)
#lgd = ax.legend(bbox_to_anchor=(1.1, 0.1))
#text = ax.text(-0.2,1.05, "Default25to35", transform=ax.transAxes) # CHANGE K_RANGE
#go.savefig('June18_recalibration2_cursor.png', bbox_extra_artists=(lgd, text), bbox_inches='tight')

fig['layout']['xaxis'].update(title='Wavelength (nm)', range=[364.8, 365.05], dtick=0.01, autorange=False)
fig['layout']['yaxis'].update(title='Counts/sec', autorange=True)
fig.show()
# Out:
# ['Default (21)']
# ['Default (22)']
# ['Default (23)']
# ['Default (24)']
# ['Default (25)']
# ['Default (26)']
# ['Default (27)']
# ['Default (28)']
# ['Default (29)']
# ['Default (30)']
# ['Default (31)']
# ['Default (32)']
# ['Default (33)']
# ['Default (34)']
# ['Default (35)']
# ['Default (36)']
# ['Default (37)']
# ['Default (38)']
# ['Default (39)']
# ['Default (40)']
# ['Default (41)']
# ['Default (42)']
# ['Default (43)']
# ['Default (44)']
# <div>
#
#
#             <div id="4b5ea5cb-6e11-40df-ae07-54a6c9cb4725" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
 10174.0, 13878.0, 18961.0, 25166.0, 27201.0, 31711.0, 43809.0, 60499.0, 97225.0, 225192.0, 185146.0, 74919.0, 32954.0, 23672.0, 14243.0, 8925.0, 5467.0, 4399.0, 3499.0, 2333.0, 2379.0, 1784.0, 1632.0, 1525.0, 1802.0, 1298.0, 1341.0, 1114.0, 1051.0, 965.0, 1036.0, 946.0, 834.0, 1079.0, 767.0, 825.0, 521.0, 690.0, 620.0, 641.0, 552.0, 609.0, 617.0, 484.0, 485.0, 463.0, 426.0, 404.0]}, {"mode": "lines", "name": "2", "type": "scatter", "x": [364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364.965, 364.97, 364.975, 364.98, 364.985, 364.99, 364.995, 365.0, 365.005, 365.01, 365.015, 365.02, 365.025, 365.03, 365.035, 365.04, 365.045, 365.05, 365.055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 365.16, 365.165, 365.17, 365.175, 365.18, 365.185, 365.19, 365.195, 365.2], "y": [139.0, 231.0, 222.0, 288.0, 216.0, 223.0, 273.0, 263.0, 311.0, 306.0, 423.0, 359.0, 459.0, 235.0, 400.0, 382.0, 350.0, 451.0, 370.0, 392.0, 501.0, 499.0, 761.0, 462.0, 904.0, 945.0, 1025.0, 1724.0, 2239.0, 3525.0, 5872.0, 9419.0, 13977.0, 17663.0, 23222.0, 27369.0, 32257.0, 38970.0, 56058.0, 93488.0, 218345.0, 183757.0, 85881.0, 42116.0, 21397.0, 17023.0, 9893.0, 5178.0, 4459.0, 3211.0, 2830.0, 2357.0, 1891.0, 1670.0, 1571.0, 1585.0, 1395.0, 1298.0, 1024.0, 885.0, 914.0, 973.0, 942.0, 9 ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

FileNames = [0]*11
for i in range(len(FileNames)):
    string = 'Default (%.0f)' %(i+45)
    FileNames[i] = [string]
    print(FileNames[i])

fig = go.Figure()

for j in range(len(FileNames)):

    df = pd.read_csv(FileNames[j][0])
    dataWheader = np.array(df)

    data = dataWheader[2::]
    Wavelength = [0]*len(data) 
    Count = [0]*len(data)
    MaxLoc = [0]*len(data)
    for i in range(len(data)):
        step_0 = str(data[i]).split('\\t')
        Wavelength[i] = float(step_0[0][2::])
        Count[i] = float(step_0[1][0:-2])
    
     # Add traces
    fig.add_trace(go.Scatter(x=Wavelength, y=Count,
                    mode='lines',
                    name='%.0f' %j))

#plt.legend()
#plt.xlim(364.85, 365.025)
#lgd = ax.legend(bbox_to_anchor=(1.1, 0.1))
#text = ax.text(-0.2,1.05, "Default25to35", transform=ax.transAxes) # CHANGE K_RANGE
#go.savefig('June18_recalibration2_cursor.png', bbox_extra_artists=(lgd, text), bbox_inches='tight')

fig['layout']['xaxis'].update(title='Wavelength (nm)', range=[364.8, 365.05], dtick=0.01, autorange=False)
fig['layout']['yaxis'].update(title='Counts/sec', autorange=True)
fig.show()
# Out:
# ['Default (45)']
# ['Default (46)']
# ['Default (47)']
# ['Default (48)']
# ['Default (49)']
# ['Default (50)']
# ['Default (51)']
# ['Default (52)']
# ['Default (53)']
# ['Default (54)']
# ['Default (55)']
# <div>
#
#
#             <div id="c5a820eb-4fea-4c61-a519-d8565be34892" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c5a820eb-4fea-4c61-a519-d8565be34892")) {
#                     Plotly.newPlot(
#                         'c5a820eb-4fea-4c61-a519-d8565be34892',
#                         [{"mode": "lines", "name": "0", "type": "scatter", "x": [364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364.965, 364.97, 364.975, 364.98, 364.985, 364.99, 364.995, 365.0, 365.005, 365.01, 365.015, 365.02, 365.025, 365.03, 365.035, 365.04, 365.045, 365.05, 365.055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 365.16, 365.165, 365.17, 365.175, 365.18, 365.185, 365.19, 365.195, 365.2], "y": [191.0, 221.0, 296.0, 238.0, 191.0, 289.0, 305.0, 313.0, 317.0, 358.0, 266.0, 304.0, 316.0, 337.0, 428.0, 417.0, 409.0, 541.0, 446.0, 344.0, 468.0, 387.0, 612.0, 635.0, 657.0, 773.0, 1006.0, 863.0, 1083.0, 1738.0, 2808.0, 4979.0, 7179.0, 10733.0, 15558.0, 20694.0, 24098.0, 29375.0, 32822.0, 44254.0, 59288.0, 127373.0, 233286.0, 141927.0, 65487.0, 33708.0, 19665.0, 12999.0, 6635.0, 4734.0, 3900.0, 3125.0, 2226.0, 2199.0, 1652.0, 1639.0, 1507.0, 1538.0, 1315.0, 1361.0, 1106.0, 1226.0, 1107.0, 971.0, 831.0, 977.0, 754.0, 688.0, 658.0, 649.0, 615.0, 614.0, 671.0, 791.0, 670.0, 626.0, 432.0, 487.0, 412.0, 500.0, 326.0]}, {"mode": "lines", "name": "1", "type": "scatter", "x": [364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364