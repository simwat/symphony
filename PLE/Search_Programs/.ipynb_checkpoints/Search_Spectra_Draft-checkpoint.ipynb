# %%
# This program searches up data files containing specific sample names, within a local directory

import os
rootdir = '/home/jupyter/.local/share/jupyter/symphony/PLE'

# input 
input1 = input() 
  
# output 
print(input1) 


for subdir, dirs, files in os.walk(rootdir): # for every folder and file in the root directory
    for file in files: # for every file
        if '.' not in file:
            f = open(os.path.join(subdir, file)) # open the file
            file_contents = f.read() #
            if input1 in file_contents:
                print(os.path.join(subdir, file))
                with open(os.path.join(subdir, file)) as openfile:
                    for line in openfile:
                        for part in line.split():
                            if 'Start' in part:
                                print(line[0::])
# Out:
# Start
# Start

# %%
import os
rootdir = '/home/jupyter/.local/share/jupyter'
for subdir, dirs, files in os.walk(rootdir): # for every folder and file in the root directory
    for file in files:
        print(os.path.join(subdir, file))
# Out:
# /home/jupyter/.local/share/jupyter/nbsignatures.db
# /home/jupyter/.local/share/jupyter/notebook_secret
# /home/jupyter/.local/share/jupyter/runtime/kernel-3b2f2a61-8e09-4408-9e48-26205c615497.json
# /home/jupyter/.local/share/jupyter/runtime/kernel-e2c14612-104c-4615-84ca-a73fa82f6f02.json
# /home/jupyter/.local/share/jupyter/runtime/nbserver-7-open.html
# /home/jupyter/.local/share/jupyter/runtime/nbserver-7.json

# %%
# This program searches up data files containing specific sample names, within a local directory

import os
rootdir = '/home/jupyter/symphony/PLE'

# input 
input1 = input() 
  
# output 
print(input1) 


for subdir, dirs, files in os.walk(rootdir): # for every folder and file in the root directory
    for file in files: # for every file
        f = open(os.path.join(subdir, file)) # open the file
        file_contents = f.read() #
        if input1 in file_contents:
            print(os.path.join(subdir, file))
            with open(os.path.join(subdir, file)) as openfile:
                for line in openfile:
                    for part in line.split():
                        if 'Start' in part:
                            print(line[0::])
# Out:
# Start
# Start
# /home/jupyter/symphony/PLE/Search_Spectra.ipynb
#       "Start\n",
#
#       "Start\n"
#
#     "                        if 'Start' in part:\n",
#
#     "                        if 'Start' in part:\n",
#
# /home/jupyter/symphony/PLE/June18/Default (227)
# Start Time:		Thu Jun 18 2020 11:31:17 PM
#
# /home/jupyter/symphony/PLE/June18/Default (99)
# Start Time:		Thu Jun 18 2020 4:22:37 PM
#
# /home/jupyter/symphony/PLE/June18/Default (3)
# Start Time:		Thu Jun 18 2020 10:22:47 AM
#
# /home/jupyter/symphony/PLE/June18/Default (230)
# Start Time:		Thu Jun 18 2020 11:41:20 PM
#
# /home/jupyter/symphony/PLE/June18/Default (72)
# Start Time:		Thu Jun 18 2020 2:50:42 PM
#
# /home/jupyter/symphony/PLE/June18/Default (31)
# Start Time:		Thu Jun 18 2020 12:33:19 PM
#
# /home/jupyter/symphony/PLE/June18/Default (26)
# Start Time:		Thu Jun 18 2020 12:07:05 PM
#
# /home/jupyter/symphony/PLE/June18/Default (65)
# Start Time:		Thu Jun 18 2020 2:27:15 PM
#
# /home/jupyter/symphony/PLE/June18/Default (209)
# Start Time:		Thu Jun 18 2020 10:31:01 PM
#
# /home/jupyter/symphony/PLE/June18/Default (128)
# Start Time:		Thu Jun 18 2020 5:59:44 PM
#
# /home/jupyter/symphony/PLE/June18/Default (145)
# Start Time:		Thu Jun 18 2020 6:56:40 PM
#
# /home/jupyter/symphony/PLE/June18/Default (197)
# Start Time:		Thu Jun 18 2020 9:50:50 PM
#
# /home/jupyter/symphony/PLE/June18/Default (106)
# Start Time:		Thu Jun 18 2020 4:46:04 PM
#
# /home/jupyter/symphony/PLE/June18/Default (111)
# Start Time:		Thu Jun 18 2020 5:02:48 PM
#
# /home/jupyter/symphony/PLE/June18/Default (180)
# Start Time:		Thu Jun 18 2020 8:53:54 PM
#
# /home/jupyter/symphony/PLE/June18/Default (152)
# Start Time:		Thu Jun 18 2020 7:20:07 PM
#
# /home/jupyter/symphony/PLE/June18/Default (43)
# Start Time:		Thu Jun 18 2020 1:13:31 PM
#
# /home/jupyter/symphony/PLE/June18/Default (91)
# Start Time:		Thu Jun 18 2020 3:55:50 PM
#
# /home/jupyter/symphony/PLE/June18/Default (86)
# Start Time:		Thu Jun 18 2020 3:39:06 PM
#
# /home/jupyter/symphony/PLE/June18/Default (54)
# Start Time:		Thu Jun 18 2020 1:50:23 PM
#
# /home/jupyter/symphony/PLE/June18/Default (17)
# Start Time:		Thu Jun 18 2020 11:36:57 AM
#
# /home/jupyter/symphony/PLE/June18/Default (216)
# Start Time:		Thu Jun 18 2020 10:54:28 PM
#
# /home/jupyter/symphony/PLE/June18/Default (39)
# Start Time:		Thu Jun 18 2020 1:00:07 PM
#
# /home/jupyter/symphony/PLE/June18/Default (201)
# Start Time:		Thu Jun 18 2020 10:04:14 PM
#
# /home/jupyter/symphony/PLE/June18/Default (137)
# Start Time:		Thu Jun 18 2020 6:29:53 PM
#
# /home/jupyter/symphony/PLE/June18/Default (174)
# Start Time:		Thu Jun 18 2020 8:33:48 PM
#
# /home/jupyter/symphony/PLE/June18/Default (163)
# Start Time:		Thu Jun 18 2020 7:56:58 PM
#
# /home/jupyter/symphony/PLE/June18/Default (120)
# Start Time:		Thu Jun 18 2020 5:32:57 PM
#
# /home/jupyter/symphony/PLE/June18/Default (119)
# Start Time:		Thu Jun 18 2020 5:29:36 PM
#
# /home/jupyter/symphony/PLE/June18/Default (188)
# Start Time:		Thu Jun 18 2020 9:20:41 PM
#
# /home/jupyter/symphony/PLE/June18/Default (198)
# Start Time:		Thu Jun 18 2020 9:54:11 PM
#
# /home/jupyter/symphony/PLE/June18/Default (109)
# Start Time:		Thu Jun 18 2020 4:56:07 PM
#
# /home/jupyter/symphony/PLE/June18/Default (130)
# Start Time:		Thu Jun 18 2020 6:06:26 PM
#
# /home/jupyter/symphony/PLE/June18/Default (173)
# Start Time:		Thu Jun 18 2020 8:30:27 PM
#
# /home/jupyter/symphony/PLE/June18/Default (164)
# Start Time:		Thu Jun 18 2020 8:00:18 PM
#
# /home/jupyter/symphony/PLE/June18/Default (127)
# Start Time:		Thu Jun 18 2020 5:56:23 PM
#
# /home/jupyter/symphony/PLE/June18/Default (211)
# Start Time:		Thu Jun 18 2020 10:37:43 PM
#
# /home/jupyter/symphony/PLE/June18/Default (29)
# Start Time:		Thu Jun 18 2020 12:26:37 PM
#
# /home/jupyter/symphony/PLE/June18/Default (206)
# Start Time:		Thu Jun 18 2020 10:20:58 PM
#
# /home/jupyter/symphony/PLE/June18/Default (96)
# Start Time:		Thu Jun 18 2020 4:12:35 PM
#
# /home/jupyter/symphony/PLE/June18/Default (228)
# Start Time:		Thu Jun 18 2020 11:34:38 PM
#
# /home/jupyter/symphony/PLE/June18/Default (44)
# Start Time:		Thu Jun 18 2020 1:16:52 PM
#
# /home/jupyter/symphony/PLE/June18/Default (53)
# Start Time:		Thu Jun 18 2020 1:47:02 PM
#
# /home/jupyter/symphony/PLE/June18/Default (81)
# Start Time:		Thu Jun 18 2020 3:22:22 PM
#
# /home/jupyter/symphony/PLE/June18/Default (10)
# Start Time:		Thu Jun 18 2020 11:13:30 AM
#
# /home/jupyter/symphony/PLE/June18/Default (190)
# Start Time:		Thu Jun 18 2020 9:27:23 PM
#
# /home/jupyter/symphony/PLE/June18/Default (142)
# Start Time:		Thu Jun 18 2020 6:46:37 PM
#
# /home/jupyter/symphony/PLE/June18/Default (101)
# Start Time:		Thu Jun 18 2020 4:29:19 PM
#
# /home/jupyter/symphony/PLE/June18/Default (116)
# Start Time:		Thu Jun 18 2020 5:19:33 PM
#
# /home/jupyter/symphony/PLE/June18/Default (155)
# Start Time:		Thu Jun 18 2020 7:30:10 PM
#
# /home/jupyter/symphony/PLE/June18/Default (187)
# Start Time:		Thu Jun 18 2020 9:17:20 PM
#
# /home/jupyter/symphony/PLE/June18/Default (138)
# Start Time:		Thu Jun 18 2020 6:33:14 PM
#
# /home/jupyter/symphony/PLE/June18/Default (75)
# Start Time:		Thu Jun 18 2020 3:00:45 PM
#
# /home/jupyter/symphony/PLE/June18/Default (219)
# Start Time:		Thu Jun 18 2020 11:04:30 PM
#
# /home/jupyter/symphony/PLE/June18/Default (36)
# Start Time:		Thu Jun 18 2020 12:50:04 PM
#
# /home/jupyter/symphony/PLE/June18/Default (21)
# Start Time:		Thu Jun 18 2020 11:50:21 AM
#
# /home/jupyter/symphony/PLE/June18/Default (62)
# Start Time:		Thu Jun 18 2020 2:17:12 PM
#
# /home/jupyter/symphony/PLE/June18/Default (220)
# Start Time:		Thu Jun 18 2020 11:07:51 PM
#
# /home/jupyter/symphony/PLE/June18/Default (4)
# Start Time:		Thu Jun 18 2020 10:53:24 AM
#
# /home/jupyter/symphony/PLE/June18/Default (89)
# Start Time:		Thu Jun 18 2020 3:49:09 PM
#
# /home/jupyter/symphony/PLE/June18/Default (18)
# Start Time:		Thu Jun 18 2020 11:40:18 AM
#
# /home/jupyter/symphony/PLE/June18/Default (217)
# Start Time:		Thu Jun 18 2020 10:57:49 PM
#
# /home/jupyter/symphony/PLE/June18/Default (38)
# Start Time:		Thu Jun 18 2020 12:56:46 PM
#
# /home/jupyter/symphony/PLE/June18/Default (200)
# Start Time:		Thu Jun 18 2020 10:00:53 PM
#
# /home/jupyter/symphony/PLE/June18/Default (90)
# Start Time:		Thu Jun 18 2020 3:52:30 PM
#
# /home/jupyter/symphony/PLE/June18/Default (42)
# Start Time:		Thu Jun 18 2020 1:10:10 PM
#
# /home/jupyter/symphony/PLE/June18/Default (55)
# Start Time:		Thu Jun 18 2020 1:53:44 PM
#
# /home/jupyter/symphony/PLE/June18/Default (87)
# Start Time:		Thu Jun 18 2020 3:42:27 PM
#
# /home/jupyter/symphony/PLE/June18/Default (16)
# Start Time:		Thu Jun 18 2020 11:33:36 AM
#
# /home/jupyter/symphony/PLE/June18/Default (118)
# Start Time:		Thu Jun 18 2020 5:26:15 PM
#
# /home/jupyter/symphony/PLE/June18/Default (189)
# Start Time:		Thu Jun 18 2020 9:24:02 PM
#
# /home/jupyter/symphony/PLE/June18/Default (136)
# Start Time:		Thu Jun 18 2020 6:26:32 PM
#
# /home/jupyter/symphony/PLE/June18/Default (175)
# Start Time:		Thu Jun 18 2020 8:37:09 PM
#
# /home/jupyter/symphony/PLE/June18/Default (162)
# Start Time:		Thu Jun 18 2020 7:53:37 PM
#
# /home/jupyter/symphony/PLE/June18/Default (121)
# Start Time:		Thu Jun 18 2020 5:36:18 PM
#
# /home/jupyter/symphony/PLE/June18/Default (73)
# Start Time:		Thu Jun 18 2020 2:54:03 PM
#
# /home/jupyter/symphony/PLE/June18/Default (30)
# Start Time:		Thu Jun 18 2020 12:29:58 PM
#
# /home/jupyter/symphony/PLE/June18/Default (27)
# Start Time:		Thu Jun 18 2020 12:15:43 PM
#
# /home/jupyter/symphony/PLE/June18/Default (208)
# Start Time:		Thu Jun 18 2020 10:27:40 PM
#
# /home/jupyter/symphony/PLE/June18/Default (64)
# Start Time:		Thu Jun 18 2020 2:23:54 PM
#
# /home/jupyter/symphony/PLE/June18/Default (2)
# Start Time:		Thu Jun 18 2020 10:18:40 AM
#
# /home/jupyter/symphony/PLE/June18/Default (226)
# Start Time:		Thu Jun 18 2020 11:27:57 PM
#
# /home/jupyter/symphony/PLE/June18/Default (98)
# Start Time:		Thu Jun 18 2020 4:19:17 PM
#
# /home/jupyter/symphony/PLE/June18/Default (231)
# Start Time:		Thu Jun 18 2020 11:44:41 PM
#
# /home/jupyter/symphony/PLE/June18/Default (196)
# Start Time:		Thu Jun 18 2020 9:47:29 PM
#
# /home/jupyter/symphony/PLE/June18/Default (144)
# Start Time:		Thu Jun 18 2020 6:53:19 PM
#
# /home/jupyter/symphony/PLE/June18/Default (107)
# Start Time:		Thu Jun 18 2020 4:49:25 PM
#
# /home/jupyter/symphony/PLE/June18/Default (110)
# Start Time:		Thu Jun 18 2020 4:59:27 PM
#
# /home/jupyter/symphony/PLE/June18/Default (153)
# Start Time:		Thu Jun 18 2020 7:23:28 PM
#
# /home/jupyter/symphony/PLE/June18/Default (181)
# Start Time:		Thu Jun 18 2020 8:57:15 PM
#
# /home/jupyter/symphony/PLE/June18/Default (129)
# Start Time:		Thu Jun 18 2020 6:03:05 PM
#
# /home/jupyter/symphony/PLE/June18/Default (139)
# Start Time:		Thu Jun 18 2020 6:36:34 PM
#
# /home/jupyter/symphony/PLE/June18/Default (143)
# Start Time:		Thu Jun 18 2020 6:49:58 PM
#
# /home/jupyter/symphony/PLE/June18/Default (191)
# Start Time:		Thu Jun 18 2020 9:30:44 PM
#
# /home/jupyter/symphony/PLE/June18/Default (100)
# Start Time:		Thu Jun 18 2020 4:25:58 PM
#
# /home/jupyter/symphony/PLE/June18/Default (117)
# Start Time:		Thu Jun 18 2020 5:22:54 PM
#
# /home/jupyter/symphony/PLE/June18/Default (186)
# Start Time:		Thu Jun 18 2020 9:14:00 PM
#
# /home/jupyter/symphony/PLE/June18/Default (154)
# Start Time:		Thu Jun 18 2020 7:26:49 PM
#
# /home/jupyter/symphony/PLE/June18/Default (5)
# Start Time:		Thu Jun 18 2020 10:56:45 AM
#
# /home/jupyter/symphony/PLE/June18/Default (221)
# Start Time:		Thu Jun 18 2020 11:11:12 PM
#
# /home/jupyter/symphony/PLE/June18/Default (88)
# Start Time:		Thu Jun 18 2020 3:45:48 PM
#
# /home/jupyter/symphony/PLE/June18/Default (19)
# Start Time:		Thu Jun 18 2020 11:43:38 AM
#
# /home/jupyter/symphony/PLE/June18/Default (218)
# Start Time:		Thu Jun 18 2020 11:01:09 PM
#
# /home/jupyter/symphony/PLE/June18/Default (74)
# Start Time:		Thu Jun 18 2020 2:57:24 PM
#
# /home/jupyter/symphony/PLE/June18/Default (37)
# Start Time:		Thu Jun 18 2020 12:53:25 PM
#
# /home/jupyter/symphony/PLE/June18/Default (20)
# Start Time:		Thu Jun 18 2020 11:47:00 AM
#
# /home/jupyter/symphony/PLE/June18/Default (63)
# Start Time:		Thu Jun 18 2020 2:20:33 PM
#
# /home/jupyter/symphony/PLE/June18/Default (131)
# Start Time:		Thu Jun 18 2020 6:09:47 PM
#
# /home/jupyter/symphony/PLE/June18/Default (172)
# Start Time:		Thu Jun 18 2020 8:27:06 PM
#
# /home/jupyter/symphony/PLE/June18/Default (165)
# Start Time:		Thu Jun 18 2020 8:03:39 PM
#
# /home/jupyter/symphony/PLE/June18/Default (126)
# Start Time:		Thu Jun 18 2020 5:53:02 PM
#
# /home/jupyter/symphony/PLE/June18/Default (199)
# Start Time:		Thu Jun 18 2020 9:57:32 PM
#
# /home/jupyter/symphony/PLE/June18/Default (108)
# Start Time:		Thu Jun 18 2020 4:52:46 PM
#
# /home/jupyter/symphony/PLE/June18/Default (45)
# Start Time:		Thu Jun 18 2020 1:20:14 PM
#
# /home/jupyter/symphony/PLE/June18/Default (97)
# Start Time:		Thu Jun 18 2020 4:15:56 PM
#
# /home/jupyter/symphony/PLE/June18/Default (229)
# Start Time:		Thu Jun 18 2020 11:37:59 PM
#
# /home/jupyter/symphony/PLE/June18/Default (80)
# Start Time:		Thu Jun 18 2020 3:19:01 PM
#
# /home/jupyter/symphony/PLE/June18/Default (52)
# Start Time:		Thu Jun 18 2020 1:43:41 PM
#
# /home/jupyter/symphony/PLE/June18/Default (11)
# Start Time:		Thu Jun 18 2020 11:16:51 AM
#
# /home/jupyter/symphony/PLE/June18/Default (210)
# Start Time:		Thu Jun 18 2020 10:34:22 PM
#
# /home/jupyter/symphony/PLE/June18/Default (28)
# Start Time:		Thu Jun 18 2020 12:23:16 PM
#
# /home/jupyter/symphony/PLE/June18/Default (207)
# Start Time:		Thu Jun 18 2020 10:24:19 PM
#
# /home/jupyter/symphony/PLE/June18/Default (213)
# Start Time:		Thu Jun 18 2020 10:44:25 PM
#
# /home/jupyter/symphony/PLE/June18/Default (68)
# Start Time:		Thu Jun 18 2020 2:37:18 PM
#
# /home/jupyter/symphony/PLE/June18/Default (204)
# Start Time:		Thu Jun 18 2020 10:14:16 PM
#
# /home/jupyter/symphony/PLE/June18/Default
# Start Time:		Thu Jun 18 2020 10:07:33 AM
#
# /home/jupyter/symphony/PLE/June18/Default (46)
# Start Time:		Thu Jun 18 2020 1:23:35 PM
#
# /home/jupyter/symphony/PLE/June18/Default (94)
# Start Time:		Thu Jun 18 2020 4:05:53 PM
#
# /home/jupyter/symphony/PLE/June18/Default (12)
# Start Time:		Thu Jun 18 2020 11:20:12 AM
#
# /home/jupyter/symphony/PLE/June18/Default (83)
# Start Time:		Thu Jun 18 2020 3:29:04 PM
#
# /home/jupyter/symphony/PLE/June18/Default (51)
# Start Time:		Thu Jun 18 2020 1:40:20 PM
#
# /home/jupyter/symphony/PLE/June18/Default (148)
# Start Time:		Thu Jun 18 2020 7:06:43 PM
#
# /home/jupyter/symphony/PLE/June18/Default (171)
# Start Time:		Thu Jun 18 2020 8:23:45 PM
#
# /home/jupyter/symphony/PLE/June18/Default (132)
# Start Time:		Thu Jun 18 2020 6:13:08 PM
#
# /home/jupyter/symphony/PLE/June18/Default (125)
# Start Time:		Thu Jun 18 2020 5:49:41 PM
#
# /home/jupyter/symphony/PLE/June18/Default (166)
# Start Time:		Thu Jun 18 2020 8:07:00 PM
#
# /home/jupyter/symphony/PLE/June18/Default (34)
# Start Time:		Thu Jun 18 2020 12:43:22 PM
#
# /home/jupyter/symphony/PLE/June18/Default (77)
# Start Time:		Thu Jun 18 2020 3:08:26 PM
#
# /home/jupyter/symphony/PLE/June18/Default (60)
# Start Time:		Thu Jun 18 2020 2:10:30 PM
#
# /home/jupyter/symphony/PLE/June18/Default (23)
# Start Time:		Thu Jun 18 2020 11:57:02 AM
#
# /home/jupyter/symphony/PLE/June18/Default (6)
# Start Time:		Thu Jun 18 2020 11:00:06 AM
#
# /home/jupyter/symphony/PLE/June18/Default (222)
# Start Time:		Thu Jun 18 2020 11:14:33 PM
#
# /home/jupyter/symphony/PLE/June18/Default (235)
# Start Time:		Thu Jun 18 2020 11:58:05 PM
#
# /home/jupyter/symphony/PLE/June18/Default (59)
# Start Time:		Thu Jun 18 2020 2:07:09 PM
#
# /home/jupyter/symphony/PLE/June18/Default (103)
# Start Time:		Thu Jun 18 2020 4:36:01 PM
#
# /home/jupyter/symphony/PLE/June18/Default (140)
# Start Time:		Thu Jun 18 2020 6:39:55 PM
#
# /home/jupyter/symphony/PLE/June18/Default (192)
# Start Time:		Thu Jun 18 2020 9:34:05 PM
#
# /home/jupyter/symphony/PLE/June18/Default (185)
# Start Time:		Thu Jun 18 2020 9:10:39 PM
#
# /home/jupyter/symphony/PLE/June18/Default (157)
# Start Time:		Thu Jun 18 2020 7:36:52 PM
#
# /home/jupyter/symphony/PLE/June18/Default (114)
# Start Time:		Thu Jun 18 2020 5:12:51 PM
#
# /home/jupyter/symphony/PLE/June18/Default (179)
# Start Time:		Thu Jun 18 2020 8:50:33 PM
#
# /home/jupyter/symphony/PLE/June18/Default (169)
# Start Time:		Thu Jun 18 2020 8:17:03 PM
#
# /home/jupyter/symphony/PLE/June18/Default (104)
# Start Time:		Thu Jun 18 2020 4:39:22 PM
#
# /home/jupyter/symphony/PLE/June18/Default (195)
# Start Time:		Thu Jun 18 2020 9:44:08 PM
#
# /home/jupyter/symphony/PLE/June18/Default (147)
# Start Time:		Thu Jun 18 2020 7:03:22 PM
#
# /home/jupyter/symphony/PLE/June18/Default (150)
# Start Time:		Thu Jun 18 2020 7:13:25 PM
#
# /home/jupyter/symphony/PLE/June18/Default (182)
# Start Time:		Thu Jun 18 2020 9:00:36 PM
#
# /home/jupyter/symphony/PLE/June18/Default (113)
# Start Time:		Thu Jun 18 2020 5:09:30 PM
#
# /home/jupyter/symphony/PLE/June18/Default (1)
# Start Time:		Thu Jun 18 2020 10:14:06 AM
#
# /home/jupyter/symphony/PLE/June18/Default (225)
# Start Time:		Thu Jun 18 2020 11:24:36 PM
#
# /home/jupyter/symphony/PLE/June18/Default (49)
# Start Time:		Thu Jun 18 2020 1:33:38 PM
#
# /home/jupyter/symphony/PLE/June18/Default (232)
# Start Time:		Thu Jun 18 2020 11:48:02 PM
#
# /home/jupyter/symphony/PLE/June18/Default (33)
# Start Time:		Thu Jun 18 2020 12:40:01 PM
#
# /home/jupyter/symphony/PLE/June18/Default (70)
# Start Time:		Thu Jun 18 2020 2:44:00 PM
#
# /home/jupyter/symphony/PLE/June18/Default (67)
# Start Time:		Thu Jun 18 2020 2:33:57 PM
#
# /home/jupyter/symphony/PLE/June18/Default (24)
# Start Time:		Thu Jun 18 2020 12:00:23 PM
#
# /home/jupyter/symphony/PLE/June18/Default (176)
# Start Time:		Thu Jun 18 2020 8:40:30 PM
#
# /home/jupyter/symphony/PLE/June18/Default (135)
# Start Time:		Thu Jun 18 2020 6:23:11 PM
#
# /home/jupyter/symphony/PLE/June18/Default (122)
# Start Time:		Thu Jun 18 2020 5:39:38 PM
#
# /home/jupyter/symphony/PLE/June18/Default (161)
# Start Time:		Thu Jun 18 2020 7:50:16 PM
#
# /home/jupyter/symphony/PLE/June18/Default (158)
# Start Time:		Thu Jun 18 2020 7:40:13 PM
#
# /home/jupyter/symphony/PLE/June18/Default (9)
# Start Time:		Thu Jun 18 2020 11:10:09 AM
#
# /home/jupyter/symphony/PLE/June18/Default (93)
# Start Time:		Thu Jun 18 2020 4:02:32 PM
#
# /home/jupyter/symphony/PLE/June18/Default (41)
# Start Time:		Thu Jun 18 2020 1:06:49 PM
#
# /home/jupyter/symphony/PLE/June18/Default (15)
# Start Time:		Thu Jun 18 2020 11:30:15 AM
#
# /home/jupyter/symphony/PLE/June18/Default (56)
# Start Time:		Thu Jun 18 2020 1:57:05 PM
#
# /home/jupyter/symphony/PLE/June18/Default (84)
# Start Time:		Thu Jun 18 2020 3:32:24 PM
#
# /home/jupyter/symphony/PLE/June18/Default (78)
# Start Time:		Thu Jun 18 2020 3:12:20 PM
#
# /home/jupyter/symphony/PLE/June18/Default (214)
# Start Time:		Thu Jun 18 2020 10:47:46 PM
#
# /home/jupyter/symphony/PLE/June18/Default (203)
# Start Time:		Thu Jun 18 2020 10:10:55 PM
#
# /home/jupyter/symphony/PLE/June18/Default (223)
# Start Time:		Thu Jun 18 2020 11:17:54 PM
#
# /home/jupyter/symphony/PLE/June18/Default (7)
# Start Time:		Thu Jun 18 2020 11:03:27 AM
#
# /home/jupyter/symphony/PLE/June18/Default (58)
# Start Time:		Thu Jun 18 2020 2:03:48 PM
#
# /home/jupyter/symphony/PLE/June18/Default (234)
# Start Time:		Thu Jun 18 2020 11:54:44 PM
#
# /home/jupyter/symphony/PLE/June18/Default (35)
# Start Time:		Thu Jun 18 2020 12:46:43 PM
#
# /home/jupyter/symphony/PLE/June18/Default (76)
# Start Time:		Thu Jun 18 2020 3:04:05 PM
#
# /home/jupyter/symphony/PLE/June18/Default (61)
# Start Time:		Thu Jun 18 2020 2:13:51 PM
#
# /home/jupyter/symphony/PLE/June18/Default (22)
# Start Time:		Thu Jun 18 2020 11:53:41 AM
#
# /home/jupyter/symphony/PLE/June18/Default (178)
# Start Time:		Thu Jun 18 2020 8:47:12 PM
#
# /home/jupyter/symphony/PLE/June18/Default (102)
# Start Time:		Thu Jun 18 2020 4:32:40 PM
#
# /home/jupyter/symphony/PLE/June18/Default (193)
# Start Time:		Thu Jun 18 2020 9:37:26 PM
#
# /home/jupyter/symphony/PLE/June18/Default (141)
# Start Time:		Thu Jun 18 2020 6:43:16 PM
#
# /home/jupyter/symphony/PLE/June18/Default (156)
# Start Time:		Thu Jun 18 2020 7:33:31 PM
#
# /home/jupyter/symphony/PLE/June18/Default (184)
# Start Time:		Thu Jun 18 2020 9:07:18 PM
#
# /home/jupyter/symphony/PLE/June18/Default (115)
# Start Time:		Thu Jun 18 2020 5:16:12 PM
#
# /home/jupyter/symphony/PLE/June18/Default (95)
# Start Time:		Thu Jun 18 2020 4:09:14 PM
#
# /home/jupyter/symphony/PLE/June18/Default (47)
# Start Time:		Thu Jun 18 2020 1:26:56 PM
#
# /home/jupyter/symphony/PLE/June18/Default (13)
# Start Time:		Thu Jun 18 2020 11:23:33 AM

# %%
# This program searches up data files containing specific sample names, within a local directory

import os
rootdir = '/home/jupyter/symphony/PLE'

# input 
input1 = input() 
  
# output 
print(input1) 


for subdir, dirs, files in os.walk(rootdir): # for every folder and file in the root directory
    for file in files: # for every file
        if '.' not in os.path.join(subdir, file): # if the file name doesn't have an extension
            f = open(os.path.join(subdir, file)) # open the file
            file_contents = f.read() #
            for line in file_contents: 
                for part in line.split():
                    if input1 in part:
                        print(os.path.join(subdir, file))
# Out:
# Chris
# Chris
