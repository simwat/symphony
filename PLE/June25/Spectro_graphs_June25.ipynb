# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

FileNames = [0]*108
for i in range(len(FileNames)):
    string = 'Default (%.0f)' %(i+1)
    FileNames[i] = [string]
    print(FileNames[i])

fig = go.Figure()

for j in range(len(FileNames)):

    df = pd.read_csv(FileNames[j][0])
    dataWheader = np.array(df)

    data = dataWheader[2::]
    Wavelength = [0]*len(data) 
    Count = [0]*len(data)
    MaxLoc = [0]*len(data)
    for i in range(len(data)):
        step_0 = str(data[i]).split('\\t')
        Wavelength[i] = float(step_0[0][2::])
        Count[i] = float(step_0[1][0:-2])
    
     # Add traces
    fig.add_trace(go.Scatter(x=Wavelength, y=Count,
                    mode='lines',
                    name='%.0f' %j))

#plt.legend()
#plt.xlim(364.85, 365.025)
#lgd = ax.legend(bbox_to_anchor=(1.1, 0.1))
#text = ax.text(-0.2,1.05, "Default25to35", transform=ax.transAxes) # CHANGE K_RANGE
#go.savefig('June18_recalibration2_cursor.png', bbox_extra_artists=(lgd, text), bbox_inches='tight')

fig['layout']['xaxis'].update(title='Wavelength (nm)', range=[364.6, 364.95], dtick=0.01, autorange=False)
fig['layout']['yaxis'].update(title='Counts/sec', autorange=True)
fig.show()
# Out:
# ['Default (1)']
# ['Default (2)']
# ['Default (3)']
# ['Default (4)']
# ['Default (5)']
# ['Default (6)']
# ['Default (7)']
# ['Default (8)']
# ['Default (9)']
# ['Default (10)']
# ['Default (11)']
# ['Default (12)']
# ['Default (13)']
# ['Default (14)']
# ['Default (15)']
# ['Default (16)']
# ['Default (17)']
# ['Default (18)']
# ['Default (19)']
# ['Default (20)']
# ['Default (21)']
# ['Default (22)']
# ['Default (23)']
# ['Default (24)']
# ['Default (25)']
# ['Default (26)']
# ['Default (27)']
# ['Default (28)']
# ['Default (29)']
# ['Default (30)']
# ['Default (31)']
# ['Default (32)']
# ['Default (33)']
# ['Default (34)']
# ['Default (35)']
# ['Default (36)']
# ['Default (37)']
# ['Default (38)']
# ['Default (39)']
# ['Default (40)']
# ['Default (41)']
# ['Default (42)']
# ['Default (43)']
# ['Default (44)']
# ['Default (45)']
# ['Default (46)']
# ['Default (47)']
# ['Default (48)']
# ['Default (49)']
# ['Default (50)']
# ['Default (51)']
# ['Default (52)']
# ['Default (53)']
# ['Default (54)']
# ['Default (55)']
# ['Default (56)']
# ['Default (57)']
# ['Default (58)']
# ['Default (59)']
# ['Default (60)']
# ['Default (61)']
# ['Default (62)']
# ['Default (63)']
# ['Default (64)']
# ['Default (65)']
# ['Default (66)']
# ['Default (67)']
# ['Default (68)']
# ['Default (69)']
# ['Default (70)']
# ['Default (71)']
# ['Default (72)']
# ['Default (73)']
# ['Default (74)']
# ['Default (75)']
# ['Default (76)']
# ['Default (77)']
# ['Default (78)']
# ['Default (79)']
# ['Default (80)']
# ['Default (81)']
# ['Default (82)']
# ['Default (83)']
# ['Default (84)']
# ['Default (85)']
# ['Default (86)']
