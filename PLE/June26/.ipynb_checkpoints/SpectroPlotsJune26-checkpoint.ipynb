# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

FileNames = [0]*11
for i in range(len(FileNames)):
    string = 'Default (%.0f)' %(i+1)
    FileNames[i] = [string]
    print(FileNames[i])

fig = go.Figure()

for j in range(len(FileNames)):

    df = pd.read_csv(FileNames[j][0])
    dataWheader = np.array(df)

    data = dataWheader[2::]
    Wavelength = [0]*len(data) 
    Count = [0]*len(data)
    MaxLoc = [0]*len(data)
    for i in range(len(data)):
        step_0 = str(data[i]).split('\\t')
        Wavelength[i] = float(step_0[0][2::])
        Count[i] = float(step_0[1][0:-2])
    
     # Add traces
    fig.add_trace(go.Scatter(x=Wavelength, y=Count,
                    mode='lines',
                    name='%.0f' %j))

#plt.legend()
#plt.xlim(364.85, 365.025)
#lgd = ax.legend(bbox_to_anchor=(1.1, 0.1))
#text = ax.text(-0.2,1.05, "Default25to35", transform=ax.transAxes) # CHANGE K_RANGE
#go.savefig('June18_recalibration2_cursor.png', bbox_extra_artists=(lgd, text), bbox_inches='tight')

fig['layout']['xaxis'].update(title='Wavelength (nm)', range=[365, 365.05], dtick=0.005, autorange=False)
fig['layout']['yaxis'].update(title='Counts/sec', autorange=True)
fig.show()
# Out:
# ['Default (1)']
# ['Default (2)']
# ['Default (3)']
# ['Default (4)']
# ['Default (5)']
# ['Default (6)']
# ['Default (7)']
# ['Default (8)']
# ['Default (9)']
# ['Default (10)']
# ['Default (11)']
# <div>
#
#
#             <div id="2fad5d9b-2804-40f5-90d5-149182f79b1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fad5d9b-2804-40f5-90d5-149182f79b1e")) {
#                     Plotly.newPlot(
#                         '2fad5d9b-2804-40f5-90d5-149182f79b1e',
#                         [{"mode": "lines", "name": "0", "type": "scatter", "x": [364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364.965, 364.97, 364.975, 364.98, 364.985, 364.99, 364.995, 365.0, 365.005, 365.01, 365.015, 365.02, 365.025, 365.03, 365.035, 365.04, 365.045, 365.05, 365.055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 365.16, 365.165, 365.17, 365.175, 365.18, 365.185, 365.19, 365.195, 365.2], "y": [267.0, 195.0, 384.0, 261.0, 255.0, 345.0, 244.0, 223.0, 278.0, 405.0, 258.0, 271.0, 256.0, 273.0, 363.0, 336.0, 343.0, 427.0, 404.0, 431.0, 390.0, 344.0, 540.0, 553.0, 671.0, 481.0, 568.0, 780.0, 794.0, 1053.0, 1272.0, 2091.0, 3624.0, 5702.0, 9151.0, 12836.0, 16900.0, 20771.0, 24348.0, 28463.0, 34895.0, 45164.0, 61019.0, 133184.0, 188326.0, 126475.0, 55527.0, 31408.0, 19015.0, 12874.0, 7192.0, 4817.0, 3568.0, 3023.0, 2301.0, 2012.0, 1691.0, 1414.0, 1793.0, 1288.0, 1256.0, 1358.0, 1052.0, 1222.0, 820.0, 1074.0, 844.0, 834.0, 756.0, 676.0, 563.0, 653.0, 852.0, 596.0, 539.0, 458.0, 574.0, 544.0, 410.0,