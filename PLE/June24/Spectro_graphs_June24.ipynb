# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

FileNames = [0]*123
for i in range(len(FileNames)):
    string = 'Default (%.0f)' %(i+3)
    FileNames[i] = [string]
    print(FileNames[i])

fig = go.Figure()

for j in range(len(FileNames)):

    df = pd.read_csv(FileNames[j][0])
    dataWheader = np.array(df)

    data = dataWheader[2::]
    Wavelength = [0]*len(data) 
    Count = [0]*len(data)
    MaxLoc = [0]*len(data)
    for i in range(len(data)):
        step_0 = str(data[i]).split('\\t')
        Wavelength[i] = float(step_0[0][2::])
        Count[i] = float(step_0[1][0:-2])
    
     # Add traces
    fig.add_trace(go.Scatter(x=Wavelength, y=Count,
                    mode='lines',
                    name='%.0f' %j))

#plt.legend()
#plt.xlim(364.85, 365.025)
#lgd = ax.legend(bbox_to_anchor=(1.1, 0.1))
#text = ax.text(-0.2,1.05, "Default25to35", transform=ax.transAxes) # CHANGE K_RANGE
#go.savefig('June18_recalibration2_cursor.png', bbox_extra_artists=(lgd, text), bbox_inches='tight')

fig['layout']['xaxis'].update(title='Wavelength (nm)', range=[364.9, 365], dtick=0.01, autorange=False)
fig['layout']['yaxis'].update(title='Counts/sec', autorange=True)
fig.show()
# Out:
# ['Default (3)']
# ['Default (4)']
# ['Default (5)']
# ['Default (6)']
# ['Default (7)']
# ['Default (8)']
# ['Default (9)']
# ['Default (10)']
# ['Default (11)']
# ['Default (12)']
# ['Default (13)']
# ['Default (14)']
# ['Default (15)']
# ['Default (16)']
# ['Default (17)']
# ['Default (18)']
# ['Default (19)']
# ['Default (20)']
# ['Default (21)']
# ['Default (22)']
# ['Default (23)']
# ['Default (24)']
# ['Default (25)']
# ['Default (26)']
# ['Default (27)']
# ['Default (28)']
# ['Default (29)']
# ['Default (30)']
# ['Default (31)']
# ['Default (32)']
# ['Default (33)']
# ['Default (34)']
# ['Default (35)']
# ['Default (36)']
# ['Default (37)']
# ['Default (38)']
# ['Default (39)']
# ['Default (40)']
# ['Default (41)']
# ['Default (42)']
# ['Default (43)']
# ['Default (44)']
# ['Default (45)']
# ['Default (46)']
# ['Default (47)']
# ['Default (48)']
# ['Default (49)']
# ['Default (50)']
# ['Default (51)']
# ['Default (52)']
# ['Default (53)']
# ['Default (54)']
# ['Default (55)']
# ['Default (56)']
# ['Default (57)']
# ['Default (58)']
# ['Default (59)']
# ['Default (60)']
# ['Default (61)']
# ['Default (62)']
# ['Default (63)']
# ['Default (64)']
# ['Default (65)']
# ['Default (66)']
# ['Default (67)']
# ['Default (68)']
# ['Default (69)']
# ['Default (70)']
# ['Default (71)']
# ['Default (72)']
# ['Default (73)']
# ['Default (74)']
# ['Default (75)']
# ['Default (76)']
# ['Default (77)']
# ['Default (78)']
# ['Default (79)']
# ['Default (80)']
# ['Default (81)']
# ['Default (82)']
# ['Default (83)']
# ['Default (84)']
# ['Default (85)']
# ['Default (86)']
# ['Default (87)']
# ['Default (88)']
# ['Default (89)']
# ['Default (90)']
# ['Default (91)']
# ['Default (92)']
# ['Default (93)']
# ['Default (94)']
# ['Default (95)']
# ['Default (96)']
# ['Default (97)']
# ['Default (98)']
# ['Default (99)']
# ['Default (100)']
# ['Default (101)']
# ['Default (102)']
# ['Default (103)']
# ['Default (104)']
# ['Default (105)']
# ['Default (106)']
# ['Default (107)']
# ['Default (108)']
# ['Default (109)']
# ['Default (110)']
# ['Default (111)']
# ['Default (112)']
# ['Default (113)']
# ['Default (114)']
# ['Default (115)']
# ['Default (116)']
# ['Default (117)']
# ['Default (118)']
# ['Default (119)']
# ['Default (120)']
# ['Default (121)']
# ['Default (122)']
# ['Default (123)']
# ['Default (124)']
# ['Default (125)']
# <div>
#
#
#             <div id="990bcfca-ac15-4618-99e8-c0c22acf18a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("990bcfca-ac15-4618-99e8-c0c22acf18a8")) {
#                     Plotly.newPlot(
#                         '990bcfca-ac15-4618-99e8-c0c22acf18a8',
#                         [{"mode": "lines", "name": "0", "type": "scatter", "x": [364.6, 364.605, 364.61, 364.615, 364.62, 364.625, 364.63, 364.635, 364.64, 364.645, 364.65, 364.655, 364.66, 364.665, 364.67, 364.675, 364.68, 364.685, 364.69, 364.695, 364.7, 364.705, 364.71, 364.715, 364.72, 364.725, 364.73, 364.735, 364.74, 364.745, 364.75, 364.755, 364.76, 364.765, 364.77, 364.775, 364.78, 364.785, 364.79, 364.795, 364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364.965, 364.97, 364.975, 364.98, 364.985, 364.99, 364.995, 365.0, 365.005, 365.01, 365.015, 365.02, 365.025, 365.03, 365.035, 365.04, 365.045, 365.05, 365.055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 365.16, 365.165, 365.17, 365.175, 365.18, 365.185, 365.19, 365.195, 365.2, 365.205, 365.21, 365.215, 365.22, 365.225, 365.23, 365.235, 365.24, 365.245, 365.25, 365.255, 365.26, 365.265, 365.27, 365.275, 365.28, 365.285, 365.29, 365.295, 365.3, 365.305, 365.31, 365.315, 365.32, 365.325, 365.33, 365.335, 365.34, 365.345, 365.35, 365.355, 365.36, 365.365, 365.37, 365.375, 365.38, 365.385, 365.39, 365.395, 365.4, 365.405, 365.41, 365.415, 365.42, 365.425, 365.43, 365.435, 365.44, 365.445, 365.45, 365.455, 365.46, 365.465, 365.47, 365.475, 365.48, 365.485, 365.49, 365.495, 365.5, 365.505, 365.51, 365.515, 365.52, 365.525, 365.53, 365.535, 365.54, 365.545, 365.55, 365.555, 365.56, 365.565, 365.57, 365.575, 365.58, 365.585, 365.59, 365.595, 365.6], "y": [386.0, 386.0