# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

FileNames = [0]*45
for i in range(len(FileNames)):
    string = 'Default (%.0f)' %(i+185)
    FileNames[i] = [string]
    print(FileNames[i])

fig = go.Figure()

for j in range(len(FileNames)):

    df = pd.read_csv(FileNames[j][0])
    dataWheader = np.array(df)

    data = dataWheader[2::]
    Wavelength = [0]*len(data) 
    Count = [0]*len(data)
    MaxLoc = [0]*len(data)
    for i in range(len(data)):
        step_0 = str(data[i]).split('\\t')
        Wavelength[i] = float(step_0[0][2::])
        Count[i] = float(step_0[1][0:-2])
    
     # Add traces
    fig.add_trace(go.Scatter(x=Wavelength, y=Count,
                    mode='lines',
                    name='%.0f' %j))

#plt.legend()
#plt.xlim(364.85, 365.025)
#lgd = ax.legend(bbox_to_anchor=(1.1, 0.1))
#text = ax.text(-0.2,1.05, "Default25to35", transform=ax.transAxes) # CHANGE K_RANGE
#go.savefig('June18_recalibration2_cursor.png', bbox_extra_artists=(lgd, text), bbox_inches='tight')

fig['layout']['xaxis'].update(title='Wavelength (nm)', range=[364.8, 365.2], dtick=0.01, autorange=False)
fig['layout']['yaxis'].update(title='Counts/sec', autorange=True)
fig.show()
# Out:
# ['Default (185)']
# ['Default (186)']
# ['Default (187)']
# ['Default (188)']
# ['Default (189)']
# ['Default (190)']
# ['Default (191)']
# ['Default (192)']
# ['Default (193)']
# ['Default (194)']
# ['Default (195)']
# ['Default (196)']
# ['Default (197)']
# ['Default (198)']
# ['Default (199)']
# ['Default (200)']
# ['Default (201)']
# ['Default (202)']
# ['Default (203)']
# ['Default (204)']
# ['Default (205)']
# ['Default (206)']
# ['Default (207)']
# ['Default (208)']
# ['Default (209)']
# ['Default (210)']
# ['Default (211)']
# ['Default (212)']
# ['Default (213)']
# ['Default (214)']
# ['Default (215)']
# ['Default (216)']
# ['Default (217)']
# ['Default (218)']
# ['Default (219)']
# ['Default (220)']
# ['Default (221)']
# ['Default (222)']
# ['Default (223)']
# ['Default (224)']
# ['Default (225)']
# ['Default (226)']
# ['Default (227)']
# ['Default (228)']
# ['Default (229)']
# <div>
#
#
#             <div id="42bcc07f-4a85-489d-9ff5-c3e66f9f88ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("42bcc07f-4a85-489d-9ff5-c3e66f9f88ae")) {
#                     Plotly.newPlot(
#                         '42bcc07f-4a85-489d-9ff5-c3e66f9f88ae',
#                         [{"mode": "lines", "name": "0", "type": "scatter", "x": [364.8, 364.805, 364.81, 364.815, 364.82, 364.825, 364.83, 364.835, 364.84, 364.845, 364.85, 364.855, 364.86, 364.865, 364.87, 364.875, 364.88, 364.885, 364.89, 364.895, 364.9, 364.905, 364.91, 364.915, 364.92, 364.925, 364.93, 364.935, 364.94, 364.945, 364.95, 364.955, 364.96, 364.965, 364.97, 364.975, 364.98, 364.985, 364.99, 364.995, 365.0, 365.005, 365.01, 365.015, 365.02, 365.025, 365.03, 365.035, 365.04, 365.045, 365.05, 365.055, 365.06, 365.065, 365.07, 365.075, 365.08, 365.085, 365.09, 365.095, 365.1, 365.105, 365.11, 365.115, 365.12, 365.125, 365.13, 365.135, 365.14, 365.145, 365.15, 365.155, 365.16, 365.165, 365.17, 365.175, 365.18, 365.185, 365.19, 365.195, 365.2], "y": [524.0, 550.0, 438.0, 772.0, 489.0, 619.0, 661.0, 668.0, 588.0, 645.0, 763.0, 720.0, 802.0, 666.0, 852.0, 822.0, 1019.0, 723.0, 1017.0, 968.0, 976.0, 1112.0, 1236.0, 1265.0, 1432.0, 1886.0, 2250.0, 3309.0, 4555.0, 6662.0, 12106.0, 18763.0, 26213.0, 35992.0, 50930.0, 63281.0, 68058.0, 82461.0, 117146.0, 195195.0, 344522.0, 649393.0, 308095.0, 154402.0, 88418.0, 54